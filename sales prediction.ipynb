# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sale=pd.read_csv(r"C:\Users\spriy\cttc\bigmart Test.csv")
sale
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
sale.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
sale.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
sale.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5681 entries, 0 to 5680
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            5681 non-null   object
#  1   Item_Weight                4705 non-null   float64
#  2   Item_Fat_Content           5681 non-null   object
#  3   Item_Visibility            5681 non-null   float64
#  4   Item_Type                  5681 non-null   object
#  5   Item_MRP                   5681 non-null   float64
#  6   Outlet_Identifier          5681 non-null   object
#  7   Outlet_Establishment_Year  5681 non-null   int64
#  8   Outlet_Size                4075 non-null   object
#  9   Outlet_Location_Type       5681 non-null   object
#  10  Outlet_Type                5681 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 488.3+ KB

# %%
for i in sale.columns:
    print (i,':','\n',sale[i].unique())
# Out:
# Item_Identifier :
#  ['FDW58' 'FDW14' 'NCN55' ... 'NCI29' 'FDP28' 'FDF04']
# Item_Weight :
#  [20.75   8.3   14.6    7.315    nan  9.8   19.35   6.305  5.985 16.6
#   6.59   4.785 16.75   6.135 19.85  17.85  13.6    7.1   19.2   13.65
#   6.785 13.     5.825 13.8   12.8    9.5   12.5    5.78  10.395 18.35
#  21.1   19.75   8.43  15.35   6.71  10.195 11.65  12.85  12.15  18.25
#   5.98  12.65  13.1   20.7    7.855 13.35  17.25   8.315 21.35   5.88
#   7.435 14.65  14.    18.2   17.6    7.71   7.81  16.35  16.1    5.34
#   5.51   6.61   6.38   8.71  17.75   6.44  12.6    7.935 18.5    6.035
#  11.8    6.26  16.5   15.7    6.635  8.155  6.175  8.18   8.355  6.905
#  20.35  19.25   5.48   5.425 12.1   11.     5.765  5.44   6.13   8.195
#  14.15  14.3    5.635  5.73   7.155 15.2   15.25   8.76   9.13  19.6
#  10.    11.3    6.57  13.15   4.635 10.6    9.3    7.02   7.825 19.1
#   7.51   8.85  17.35  15.15   5.46  13.5    8.275 10.8   15.5    4.905
# ...

# %%
s= sale.describe(include='all')
s
# Out:
#        Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# count             5681  4705.000000             5681      5681.000000
# unique            1543          NaN                5              NaN
# top              DRF48          NaN          Low Fat              NaN
# freq                 8          NaN             3396              NaN
# mean               NaN    12.695633              NaN         0.065684
# std                NaN     4.664849              NaN         0.051252
# min                NaN     4.555000              NaN         0.000000
# 25%                NaN     8.645000              NaN         0.027047
# 50%                NaN    12.500000              NaN         0.054154
# 75%                NaN    16.700000              NaN         0.093463
# max                NaN    21.350000              NaN         0.323637
#
#           Item_Type     Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
sale.Item_Weight.replace(np.NaN,s['Item_Weight'][4],inplace=True)

# %%
sale.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64

# %%
sale.Outlet_Size.replace(np.NaN,s['Outlet_Size'][2],inplace=True)

# %%
sale.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# dtype: int64

# %%
#describe
sale.describe(include='all')
# Out:
#        Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# count             5681  5681.000000             5681      5681.000000
# unique            1543          NaN                5              NaN
# top              DRF48          NaN          Low Fat              NaN
# freq                 8          NaN             3396              NaN
# mean               NaN    12.695633              NaN         0.065684
# std                NaN     4.245189              NaN         0.051252
# min                NaN     4.555000              NaN         0.000000
# 25%                NaN     9.195000              NaN         0.027047
# 50%                NaN    12.695633              NaN         0.054154
# 75%                NaN    15.850000              NaN         0.093463
# max                NaN    21.350000              NaN         0.323637
#
#           Item_Type     Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %% [markdown]
# ## Data analysis

# %%
import seaborn as sns

# %%
sale.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58    20.750000          Low Fat         0.007565  Snack Foods
# 1           FDW14     8.300000              reg         0.038428        Dairy
# 2           NCN55    14.600000          Low Fat         0.099575       Others
# 3           FDQ58     7.315000          Low Fat         0.015388  Snack Foods
# 4           FDY38    12.695633          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007      Medium
# 2  241.7538            OUT010                       1998      Medium
# 3  155.0340            OUT017                       2007      Medium
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
#displot
sns.displot(sale.Item_Type)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#displot
sns.displot(sale.Outlet_Establishment_Year)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#displot
sns.displot(sale.Outlet_Location_Type)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#displot
sns.displot(sale.Item_Fat_Content)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.jointplot(data=sale)
plt.show()

# %%
sns.pairplot(sale)
plt.show
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.pairplot(sale,hue='Outlet_Location_Type')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
ip= sale.drop('Outlet_Location_Type',axis=1)
op= sale.Outlet_Location_Type

# %%
ip.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58    20.750000          Low Fat         0.007565  Snack Foods
# 1           FDW14     8.300000              reg         0.038428        Dairy
# 2           NCN55    14.600000          Low Fat         0.099575       Others
# 3           FDQ58     7.315000          Low Fat         0.015388  Snack Foods
# 4           FDY38    12.695633          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007      Medium
# 2  241.7538            OUT010                       1998      Medium
# 3  155.0340            OUT017                       2007      Medium
# 4  234.2300            OUT027                       1985      Medium
#
#          Outlet_Type
# 0  Supermarket Type1
# 1  Supermarket Type1
# ...

# %%
op.head()
# Out:
# 0    Tier 1
# 1    Tier 2
# 2    Tier 3
# 3    Tier 2
# 4    Tier 3
# Name: Outlet_Location_Type, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(ip,op,test_size= 0.8)

# %%
x_train.head()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3536           NCM19        12.65          Low Fat         0.000000
# 1663           FDM56        16.70          Low Fat         0.070334
# 3044           FDZ50        12.80          Regular         0.079199
# 3188           FDY51        12.50          Low Fat         0.081299
# 3663           DRC24        17.85          Low Fat         0.024801
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3536                 Others  111.8202            OUT010
# 1663  Fruits and Vegetables  110.7912            OUT045
# 3044                  Dairy  184.6608            OUT049
# 3188                   Meat  219.0798            OUT045
# 3663            Soft Drinks  153.0998            OUT013
#
#       Outlet_Establishment_Year Outlet_Size        Outlet_Type
# 3536                       1998      Medium      Grocery Store
# 1663                       2002      Medium  Supermarket Type1
# ...

# %%
y_train.head()
# Out:
# 3536    Tier 3
# 1663    Tier 2
# 3044    Tier 1
# 3188    Tier 2
# 3663    Tier 3
# Name: Outlet_Location_Type, dtype: object
